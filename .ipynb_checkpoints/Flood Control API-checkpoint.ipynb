# %%
import pandas as pd
import plotly_express as px

# %%
#reading the csv file
df = pd.read_csv("flood_control_data.csv", sep=",")

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 SEP=  \
# ...
